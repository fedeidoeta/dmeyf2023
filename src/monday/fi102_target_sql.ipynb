# %% [markdown]
# # Crear Target
#
# ## Ejercicio 1:
# Cree el archivo `competencia_01.csv`, usando el `competencia_01_crudo.csv` con una variable adicional llamada `clase_ternaria`, que contenga las categorías **CONTINUA**, **BAJA+1** y **BAJA+2**
#
# ### Ayudita
#
# Para practicar el muy útil y necesario lenguaje **SQL**, vamos a utilizar una base de datos **OLAP** llamada **DuckDB**.
#
# La documentación la puede encontrar [aquí](https://duckdb.org/docs/archive/0.8.1/sql/introduction)
# Procedemos a instalarla, esto se debe ejecutar una sola vez

# %%
#%%bash 
#%pip install duckdb
#%pip install jupysql
#%pip install duckdb-engine
# Out:
# Requirement already satisfied: duckdb in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (0.8.1)
# [notice] A new release of pip is available: 23.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: jupysql in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (0.10.0)
# Requirement already satisfied: prettytable in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from jupysql) (3.8.0)
# Requirement already satisfied: ipython in c:\users\feder\appdata\roaming\python\python311\site-packages (from jupysql) (8.14.0)
# Requirement already satisfied: sqlalchemy in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from jupysql) (2.0.20)
# Requirement already satisfied: sqlparse in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from jupysql) (0.4.4)
# Requirement already satisfied: ipython-genutils>=0.1.0 in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from jupysql) (0.2.0)
# Requirement already satisfied: sqlglot in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from jupysql) (17.14.2)
# Requirement already satisfied: jinja2 in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from jupysql) (3.1.2)
# Requirement already satisfied: ploomber-core>=0.2.7 in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from jupysql) (0.2.14)
# Requirement already satisfied: click in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from ploomber-core>=0.2.7->jupysql) (8.1.7)
# Requirement already satisfied: pyyaml in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from ploomber-core>=0.2.7->jupysql) (6.0.1)
# Requirement already satisfied: posthog in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from ploomber-core>=0.2.7->jupysql) (3.0.2)
# Requirement already satisfied: backcall in c:\users\feder\appdata\roaming\python\python311\site-packages (from ipython->jupysql) (0.2.0)
# Requirement already satisfied: decorator in c:\users\feder\appdata\roaming\python\python311\site-packages (from ipython->jupysql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\feder\appdata\roaming\python\python311\site-packages (from ipython->jupysql) (0.18.2)
# Requirement already satisfied: matplotlib-inline in c:\users\feder\appdata\roaming\python\python311\site-packages (from ipython->jupysql) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\feder\appdata\roaming\python\python311\site-packages (from ipython->jupysql) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\feder\appdata\roaming\python\python311\site-packages (from ipython->jupysql) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\feder\appdata\roaming\python\python311\site-packages (from ipython->jupysql) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\feder\appdata\roaming\python\python311\site-packages (from ipython->jupysql) (0.6.2)
# Requirement already satisfied: traitlets>=5 in c:\users\feder\appdata\roaming\python\python311\site-packages (from ipython->jupysql) (5.9.0)
# Requirement already satisfied: colorama in c:\users\feder\appdata\roaming\python\python311\site-packages (from ipython->jupysql) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from jinja2->jupysql) (2.1.3)
# Requirement already satisfied: wcwidth in c:\users\feder\appdata\roaming\python\python311\site-packages (from prettytable->jupysql) (0.2.6)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy->jupysql) (4.7.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy->jupysql) (2.0.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\feder\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython->jupysql) (0.8.3)
# Requirement already satisfied: requests<3.0,>=2.7 in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (2.31.0)
# Requirement already satisfied: six>=1.5 in c:\users\feder\appdata\roaming\python\python311\site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (2.2.1)
# Requirement already satisfied: python-dateutil>2.1 in c:\users\feder\appdata\roaming\python\python311\site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (2.8.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\feder\appdata\roaming\python\python311\site-packages (from stack-data->ipython->jupysql) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\feder\appdata\roaming\python\python311\site-packages (from stack-data->ipython->jupysql) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\feder\appdata\roaming\python\python311\site-packages (from stack-data->ipython->jupysql) (0.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (2023.7.22)
# [notice] A new release of pip is available: 23.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: duckdb-engine in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (0.9.2)
# [notice] A new release of pip is available: 23.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: duckdb>=0.4.0 in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from duckdb-engine) (0.8.1)
# Requirement already satisfied: sqlalchemy>=1.3.22 in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from duckdb-engine) (2.0.20)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy>=1.3.22->duckdb-engine) (4.7.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy>=1.3.22->duckdb-engine) (2.0.2)

# %% [markdown]
# Configuramos el entorno de ejecución. Si ya tiene todo instalado, solo necesita ejecutar esta celda para empezar a usar **duckdb**

# %%
import duckdb
import pandas as pd

# %load_ext sql
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %sql duckdb:///:default:

# %% [markdown]
# Y ya podemos usar **SQL** dentro de una notebook!

# %%
# %%sql
# select 'hola mundo'
# Out:
#   'hola mundo'
# 0   hola mundo

# %% [markdown]
# Para cargar el archivo `.csv` a una tabla:

# %%
# %%sql
# create or replace table competencia_02 as
# select
#     *
# from read_csv_auto('C:\Users\feder\Documents\Maestria_en_Ciencia_de_datos\4_DM_en_Economia_y_Finanzas\datasets/competencia_02_julia.csv')
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %% [markdown]
# Hagamos unas queries básicas para comprobar que todo esta funcionando bien.

# %%
# %sql select * from competencia_02 limit 5
# Out:
#    numero_de_cliente  foto_mes  active_quarter  cliente_vip  internet  \
# 0           29183981    201901               1            0         1
# 1           29183981    201902               1            0         1
# 2           29183981    201903               1            0         1
# 3           29183981    201904               1            0         1
# 4           29183981    201905               1            0         1
#
#    cliente_edad  cliente_antiguedad  mrentabilidad  mrentabilidad_annual  \
# 0            48                 171        8304.31              42993.54
# 1            48                 172        5263.49              44307.54
# 2            48                 173       11046.11              52232.34
# 3            48                 174        4804.61              54863.86
# 4            48                 175           0.00                  0.00
#
#    mcomisiones  ...  Visa_fultimo_cierre  Visa_mpagado  Visa_mpagospesos  \
# 0      2501.04  ...                    8           0.0         -35773.32
# 1      1145.41  ...                    8           0.0         -55114.90
# 2      4303.03  ...                   11           0.0         -56200.22
# 3       836.72  ...                    6           0.0         -37493.99
# 4         0.00  ...                    9           0.0         -49427.69
#
#    Visa_mpagosdolares  Visa_fechaalta  Visa_mconsumototal  Visa_cconsumos  \
# 0                2.33            5148            36602.13              54
# 1               43.34            5176            39468.25              49
# 2               19.90            5207            26117.65              44
# 3                0.00            5237            39490.38              65
# 4                2.33            5268            35927.92              54
#
#    Visa_cadelantosefectivo  Visa_mpagominimo  clase_ternaria
# 0                        0           5008.71        CONTINUA
# 1                        0           4633.35        CONTINUA
# 2                        0           3612.84        CONTINUA
# 3                        0           4304.91        CONTINUA
# 4                        0           4140.69        CONTINUA
#
# [5 rows x 155 columns]

# %%
# %%sql
# select
#     foto_mes
#     , count(*) as cantidad -- cuenta cuantos casos hay en cada foto_mes
#                            -- y lo guarda en un campo llamado cantidad
# from competencia_02
# group by foto_mes
# Out:
#     foto_mes  cantidad
# 0     201901    124864
# 1     201902    125898
# 2     201903    126536
# 3     201904    127059
# 4     201905    127683
# 5     201906    129181
# 6     201907    130551
# 7     201908    132615
# 8     201909    134267
# 9     201910    136515
# 10    201911    138438
# 11    201912    140468
# 12    202001    143762
# 13    202002    146851
# 14    202003    148989
# 15    202004    149484
# 16    202005    150874
# 17    202006    153386
# 18    202007    155348
# 19    202008    156667
# 20    202009    158031
# 21    202010    159477
# 22    202011    160493
# 23    202012    161133
# 24    202101    161711
# 25    202102    162364
# 26    202103    163324
# 27    202104    163637
# 28    202105    164102
# 29    202106    164420
# 30    202107    164682

# %%
# %%sql
# with mes_1 as (
# select numero_de_cliente
# from competencia_01
# where foto_mes = '202105')
#
# select comp.numero_de_cliente,
# comp.foto_mes,
# c.numero_de_cliente
# from competencia_01 comp
# left join mes_1 c
#     on comp.numero_de_cliente = c.numero_de_cliente
# where c.numero_de_cliente is null
# Out:
#       numero_de_cliente  foto_mes  numero_de_cliente_2
# 0              29282120    202103                  NaN
# 1              29358824    202103                  NaN
# 2              29379652    202103                  NaN
# 3              29413956    202103                  NaN
# 4              29479114    202103                  NaN
# ...                 ...       ...                  ...
# 2976          181504495    202104                  NaN
# 2977          182321662    202104                  NaN
# 2978          182463626    202104                  NaN
# 2979          185451295    202104                  NaN
# 2980          185837052    202104                  NaN
#
# [2981 rows x 3 columns]

# %% [markdown]
# Perfecto, ahora cree una nueva tabla con la variable adicional que se le pide. Algunas funciones que le pueden ser útiles:  [where](https://duckdb.org/docs/sql/query_syntax/where), [left join](https://duckdb.org/docs/sql/query_syntax/from), [case statement](https://duckdb.org/docs/sql/expressions/case)

# %%
# %%sql
# select numero_de_cliente,
# foto_mes
# from competencia_01
# where numero_de_cliente = 29199353 --in (29282120, 181504495, 29183981) -- primer caso baja +1, segundo caso baja +2
# order by 2
# Out:
#    numero_de_cliente  foto_mes
# 0           29199353    202105

# %% [markdown]
# ## Query final para obtener competencia_01

# %%
# %%sql
#
# create or replace temp table competencia_02_ternaria as
#     with clientes as (
#         select
#             numero_de_cliente,
#             foto_mes,
#             last_day(strptime(foto_mes, '%Y%m') + INTERVAL 1 MONTH) as mes_mas_1,
#             last_day(strptime(foto_mes, '%Y%m') + INTERVAL 2 MONTH) as mes_mas_2,
#         from competencia_02
#     ),
#
#     mes_1 as (
#         select
#             c.numero_de_cliente,
#             c.foto_mes,
#             c1.numero_de_cliente as cliente_mas_1
#         from clientes c
#         left join competencia_02 c1
#             on c.numero_de_cliente = c1.numero_de_cliente
#             and c.mes_mas_1 = last_day(strptime(c1.foto_mes, '%Y%m'))
#      ),
#
#     mes_2 as (
#         select
#             c.numero_de_cliente,
#             c.foto_mes,
#             c1.numero_de_cliente as cliente_mas_2
#         from clientes c
#         left join competencia_02 c1
#             on c.numero_de_cliente = c1.numero_de_cliente
#             and c.mes_mas_2 = last_day(strptime(c1.foto_mes, '%Y%m'))
#     ),
#
#     max_mes as (
#         select
#             strptime(MAX(foto_mes),'%Y%m') as max_foto
#         from competencia_02
#         --group by 1
#     ),
#
#     final as (
#     select
#         c1.*,
#         case
#             when
#                 cliente_mas_1 is not null
#                 and cliente_mas_2 is null
#                 and strptime(c1.foto_mes, '%Y%m') = m.max_foto - INTERVAL 2 MONTH
#             then 'BAJA+2'
#             when
#                 cliente_mas_1 is null
#                 and cliente_mas_2 is null
#                 and strptime(c1.foto_mes, '%Y%m') <= m.max_foto - INTERVAL 1 MONTH
#             then 'BAJA+1'
#             when
#                 (strptime(c1.foto_mes, '%Y%m') <= m.max_foto - INTERVAL 1 MONTH and cliente_mas_1 is not null)
#                 or
#                 cliente_mas_2 is not null
#             then 'CONTINUA'
#             else null end clase_ternaria
#     from competencia_02 c1
#     left join mes_1 m1
#         on m1.cliente_mas_1 = c1.numero_de_cliente
#         and c1.foto_mes = m1.foto_mes
#     left join mes_2 m2
#         on m2.cliente_mas_2 = c1.numero_de_cliente
#         and c1.foto_mes = m2.foto_mes
#     cross join max_mes m
#     )
#
#     select
#        *
#     from final
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# select foto_mes, clase_ternaria, count(*)
# from competencia_02
# where foto_mes in (202101, 202102, 202103, 202104, 202105)
# group by 1,2
# order by 1 ASC, 2 DESC
# Out:
#     foto_mes clase_ternaria  count_star()
# 0     202101       CONTINUA        160283
# 1     202101         BAJA+2           802
# 2     202101         BAJA+1           626
# 3     202102       CONTINUA        160520
# 4     202102         BAJA+2          1041
# 5     202102         BAJA+1           803
# 6     202103       CONTINUA        161317
# 7     202103         BAJA+2           959
# 8     202103         BAJA+1          1048
# 9     202104       CONTINUA        161502
# 10    202104         BAJA+2          1171
# 11    202104         BAJA+1           964
# 12    202105       CONTINUA        162026
# 13    202105         BAJA+2           904
# 14    202105         BAJA+1          1172
# 15    202106         BAJA+1           910
# 16    202106            NaN        163510
# 17    202107            NaN        164682

# %%
# %%sql
# -- COPY competencia_01_ternaria TO 'C:\Users\feder\Documents\Maestria_en_Ciencia_de_datos\4_DM_en_Economia_y_Finanzas\datasets/competencia_01.csv' (FORMAT CSV, HEADER)
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %% [markdown]
# ## Pruebas con LAG

# %%
# %%sql
# select
# numero_de_cliente,
# foto_mes,
# LAG(foto_mes) OVER(partition by numero_de_cliente order by foto_mes desc) - foto_mes as dif_1,
# LAG(foto_mes,2) OVER(partition by numero_de_cliente order by foto_mes desc)- foto_mes as dif_2
# from competencia_01
# Out:
#         numero_de_cliente  foto_mes  dif_1  dif_2
# 0                29185646    202105    NaN    NaN
# 1                29185646    202104    1.0    NaN
# 2                29185646    202103    1.0    2.0
# 3                29188883    202105    NaN    NaN
# 4                29188883    202104    1.0    NaN
# ...                   ...       ...    ...    ...
# 491058          186316072    202105    NaN    NaN
# 491059          186316072    202104    1.0    NaN
# 491060          186332374    202105    NaN    NaN
# 491061          186332374    202104    1.0    NaN
# 491062          186627721    202105    NaN    NaN
#
# [491063 rows x 4 columns]

# %%
# %%sql
#
# with clientes as (
# select
# *,
# LAG(foto_mes)
#     OVER(partition by numero_de_cliente order by foto_mes desc) as mes_mas_1,
# LAG(foto_mes,2)
#     OVER(partition by numero_de_cliente order by foto_mes desc) as mes_mas_2,
# LEAD(foto_mes)
#     OVER(partition by numero_de_cliente order by foto_mes desc) as mes_menos_1,
# LEAD(foto_mes,2)
#     OVER(partition by numero_de_cliente order by foto_mes desc) as mes_menos_2
# from competencia_01),
#
# final as (
# select
#     numero_de_cliente,
#     foto_mes,
#     mes_mas_1,
#     mes_mas_2,
#     mes_menos_1,
#     mes_menos_2,
#     case
#         when ((mes_mas_1 = foto_mes+2) or (mes_mas_2 = foto_mes+2))  is not null then 'CONTINUA'
#         when ((mes_mas_1 is null)
#             and (mes_mas_2 is null)
#             and (mes_menos_1 is not null)
#             and (mes_menos_2 is not null))
#             then null
#         when foto_mes= (select max(foto_mes) from clientes) then null
#         when ((mes_mas_1 = foto_mes+1) and (mes_menos_1 = foto_mes-1)) or (mes_menos_1 is not null) then 'CONTINUA'
#         when foto_mes<> (select max(foto_mes) from clientes) and mes_mas_1 is null and mes_mas_2 is null then 'BAJA+1'
#         when foto_mes<> (select max(foto_mes) from clientes) and ((mes_mas_1 = foto_mes+1) and (mes_mas_2 is null)) then 'BAJA+2'
#         end as clase_ternaria
# from clientes
# where 1=1
#     and foto_mes = '202103'
#     --and dif_1 = 1
# )
#
# select
# clase_ternaria, count(numero_de_cliente)
# from final
# where 1=1
# --and clase_ternaria = 'CONTINUA'
# group by 1
#
#
#
# /*
# select numero_de_cliente,foto_mes,mes_mas_1, mes_mas_2,
#     case
#         when mes_mas_2 is null then 'BAJA+2'
#         when mes_mas_1 is null and mes_mas_2 is null then 'BAJA+1'
#         when ((mes_mas_1 = foto_mes+2) or (mes_mas_2 = foto_mes+2))  is not null then 'CONTINUA'
#         end as clase_ternaria
#     from clientes*/
# Out:
#   clase_ternaria  count(numero_de_cliente)
# 0       CONTINUA                    161312
# 1         BAJA+2                       963
# 2         BAJA+1                      1049

# %%
# %%sql
# select
# clase_ternaria, count(numero_de_cliente)
# from final
# where 1=1
# and fecha_mes = 202103
# --and clase_ternaria = 'CONTINUA'
# group by 1
# Out:
# RuntimeError: If using snippets, you may pass the --with argument explicitly.
# For more details please refer: https://jupysql.ploomber.io/en/latest/compose.html#with-argument
#
#
# Original error message from DB driver:
# (duckdb.CatalogException) Catalog Error: Table with name final does not exist!
# Did you mean "information_schema.tables"?
# LINE 3: from final
#              ^
# [SQL: select
# clase_ternaria, count(numero_de_cliente)
# from final
# where 1=1
# and fecha_mes = 202103
# --and clase_ternaria = 'CONTINUA'
# group by 1]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#
# If you need help solving this issue, send us a message: https://ploomber.io/community

# %% [markdown]
# ## Feature Engineering

# %%
# %%sql
# select
#     Master_Fvencimiento
#     , Visa_Fvencimiento
#     , greatest(Master_Fvencimiento, Visa_Fvencimiento) as tc_fvencimiento_mayor
#     , least(Master_Fvencimiento, Visa_Fvencimiento) as tc_fvencimiento_menor
# from competencia_01
#
# /*Tengo varios campos y quiero quedarme con el mayor y el menor valor de estos.*/
# Out:
#         Master_Fvencimiento  Visa_Fvencimiento  tc_fvencimiento_mayor  \
# 0                    -639.0             -639.0                 -639.0
# 1                    -670.0            -1035.0                 -670.0
# 2                       NaN            -2039.0                -2039.0
# 3                    -578.0            -1217.0                 -578.0
# 4                    -455.0             -578.0                 -455.0
# ...                     ...                ...                    ...
# 491058              -2190.0            -2190.0                -2190.0
# 491059              -2190.0            -2190.0                -2190.0
# 491060              -2190.0            -2190.0                -2190.0
# 491061              -2190.0            -2190.0                -2190.0
# 491062              -2190.0            -2190.0                -2190.0
#
#         tc_fvencimiento_menor
# 0                      -639.0
# 1                     -1035.0
# 2                     -2039.0
# 3                     -1217.0
# 4                      -578.0
# ...                       ...
# 491058                -2190.0
# 491059                -2190.0
# 491060                -2190.0
# 491061                -2190.0
# 491062                -2190.0
#
# [491063 rows x 4 columns]

# %%
# %%sql
#
# select
#     Master_msaldototal
#     , Visa_msaldototal
#     , Master_msaldototal + Visa_msaldototal as tc_saldo_total
# from competencia_01
#
# --operar dos variables, como por ejemplo sumarla.
# Out:
#         Master_msaldototal  Visa_msaldototal  tc_saldo_total
# 0                101627.07         229958.68       331585.75
# 1                 56055.25          44453.56       100508.81
# 2                      NaN           3941.32             NaN
# 3                     0.00          35412.09        35412.09
# 4                     0.00         324480.94       324480.94
# ...                    ...               ...             ...
# 491058                0.00              0.00            0.00
# 491059                0.00              0.00            0.00
# 491060                0.00              0.00            0.00
# 491061                0.00              0.00            0.00
# 491062                0.00              0.00            0.00
#
# [491063 rows x 3 columns]

# %%
# %%sql
#
# select
#     Master_msaldototal
#     , Visa_msaldototal
#     , ifnull(Master_msaldototal, 0) + ifnull(Visa_msaldototal, 0) as tc_saldo_total
# from competencia_01
#
# --Pero un DS de a de veras mirará los datos y se encontrará con un campo que es null cuando se lo suma a otro dará null. Esto no siempre es deseable y puede ser fácilmente evitable
# Out:
#         Master_msaldototal  Visa_msaldototal  tc_saldo_total
# 0                101627.07         229958.68       331585.75
# 1                 56055.25          44453.56       100508.81
# 2                      NaN           3941.32         3941.32
# 3                     0.00          35412.09        35412.09
# 4                     0.00         324480.94       324480.94
# ...                    ...               ...             ...
# 491058                0.00              0.00            0.00
# 491059                0.00              0.00            0.00
# 491060                0.00              0.00            0.00
# 491061                0.00              0.00            0.00
# 491062                0.00              0.00            0.00
#
# [491063 rows x 3 columns]

# %%
# %%sql
#
# CREATE MACRO suma_sin_null(a, b) AS ifnull(a, 0) + ifnull(b, 0);
#
# select distinct
#     Master_msaldototal
#     , Visa_msaldototal
#     , suma_sin_null(Master_msaldototal, Visa_msaldototal) as tc_saldo_total
# from competencia_01
# Out:
#         Master_msaldototal  Visa_msaldototal  tc_saldo_total
# 0                 32819.44          22520.20        55339.64
# 1                     0.00              0.00            0.00
# 2                     0.00          39475.87        39475.87
# 3                      NaN          10482.48        10482.48
# 4                 31840.99          40341.30        72182.29
# ...                    ...               ...             ...
# 414899                 NaN           8887.78         8887.78
# 414900                0.00           9219.43         9219.43
# 414901                0.00          24058.20        24058.20
# 414902                0.00          32556.17        32556.17
# 414903                 NaN           7137.11         7137.11
#
# [414904 rows x 3 columns]

# %%
# %%sql
#
# select
#     foto_mes
#     , cliente_antiguedad
#     , row_number() over (partition by foto_mes order by cliente_antiguedad) as cliente_antiguedad_2
#     , percent_rank() over (partition by foto_mes order by cliente_antiguedad) as cliente_antiguedad_3
#     , cume_dist() over (partition by foto_mes order by cliente_antiguedad) as cliente_antiguedad_4
#     , ntile(4) over (partition by foto_mes order by cliente_antiguedad) as cliente_antiguedad_5
#     , ntile(10) over (partition by foto_mes order by cliente_antiguedad) as cliente_antiguedad_6
#     , ntile(10) over (partition by foto_mes order by cliente_antiguedad desc) as cliente_antiguedad_7
# from competencia_01
# order by cliente_antiguedad
# Out:
#         foto_mes  cliente_antiguedad  cliente_antiguedad_2  \
# 0         202104                   1                     1
# 1         202104                   1                     2
# 2         202104                   1                     3
# 3         202104                   1                     4
# 4         202104                   1                     5
# ...          ...                 ...                   ...
# 491058    202105                 377                164100
# 491059    202105                 377                164101
# 491060    202103                 481                163324
# 491061    202104                 482                163637
# 491062    202105                 483                164102
#
#         cliente_antiguedad_3  cliente_antiguedad_4  cliente_antiguedad_5  \
# 0                   0.000000              0.001289                     1
# 1                   0.000000              0.001289                     1
# 2                   0.000000              0.001289                     1
# 3                   0.000000              0.001289                     1
# 4                   0.000000              0.001289                     1
# ...                      ...                   ...                   ...
# 491058              0.992041              0.999994                     4
# 491059              0.992041              0.999994                     4
# 491060              1.000000              1.000000                     4
# 491061              1.000000              1.000000                     4
# 491062              1.000000              1.000000                     4
#
#         cliente_antiguedad_6  cliente_antiguedad_7
# 0                          1                    10
# 1                          1                    10
# 2                          1                    10
# 3                          1                    10
# 4                          1                    10
# ...                      ...                   ...
# 491058                    10                     1
# 491059                    10                     1
# 491060                    10                     1
# 491061                    10                     1
# 491062                    10                     1
#
# [491063 rows x 8 columns]

# %% [markdown]
# ## Ejercicio 1.1
#
# * ¿Cuál es la nominalidad de cada clase?
# * ¿Cuál es la proporción del target?

# %%
# %%sql
# -- introduzca sus queries

# %% [markdown]
# Para guardar a un **.csv** simplemente debe ejecutar la siguiente sentencia

# %%
# %%sql
# COPY competencia_01 TO '/home/aleb/dmeyf23/datasets/competencia_01.csv' (FORMAT CSV, HEADER)

# %% [markdown]
# ## Ejercicio 2 - Avanzado
# Use ahora el archivo `ejercicio_target.csv` y calcule para todos los clientes en todos los periodos su **clase_ternaria** al mismo tiempo
